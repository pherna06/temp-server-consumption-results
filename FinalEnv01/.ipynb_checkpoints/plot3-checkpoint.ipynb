# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
def get_file_data(csv, pos):
    csvf = open(csv, 'r')
    csvflines = csvf.readlines()
    csvf.close()
    
    data = []    
    for line in csvflines[1:]:
        values =  line.strip('\n[]').split(',')
        data.append(float(values[pos]))
        
    return data

# %%
########################
### POWER MEAN ERROR ###
########################
key = 'power'
clr = 'blue'
pos = 8
target = 52.5
X = range(0, 201)
Xticks = np.arange(0, 201, 10)
Yticks = np.arange(0, 18, 1)

tests = [f'test-0{i}' for i in [1,4,5]]
clrs  = ['blue', 'cyan', 'midnightblue']
chkpt = 5

fig = plt.figure(figsize=(8,6), dpi=150)

ax = fig.add_subplot(111)

for test, clr in zip(tests, clrs):
    bundle = []
    for it in range(15):
        data = get_file_data(test + f'/checkpoint-{chkpt}/iter-{it}.csv', pos)
        bundle.append([ abs(x - target) for x in data ])
    bundle = np.array(bundle)
    graph = bundle.mean(axis = 0)
    
    ax.plot(
        X, graph, 
        color = clr,
        label = test,
        linestyle = '-',
        linewidth = 0.75,
        marker = '',
        alpha = 1.0
    )
    
ax.set_xlabel('Número de paso')
ax.set_xticks(Xticks)
ax.set_xticklabels(Xticks, rotation=45)

ax.set_ylabel('Error medio: potencia (w)')
ax.set_yticks(Yticks)

ax.grid(
    alpha=0.25,
    linestyle=':',
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-e4c06b4ce927> in <module>
#      21     bundle = []
#      22     for it in range(15):
# ---> 23         data = get_file_data(test + f'checkpoint-{chkpt}/iter-{it}.csv', pos)
#      24         bundle.append([ abs(x - target) for x in data ])
#      25     bundle = np.array(bundle)
#
# <ipython-input-2-5972e81dc678> in get_file_data(csv, pos)
#       1 def get_file_data(csv, pos):
# ----> 2     csvf = open(csv, 'r')
#       3     csvflines = csvf.readlines()
#       4     csvf.close()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test-01checkpoint-5/iter-0.csv'
